# %% [markdown]
# # 전남A2/졸지아
# **프로젝트 개요:** fine-tuning과 langchain을 이용한 뉴스 긍정 분석 기반 주식 자동 매수, 매도 프로그램\
# \
# **목적:** 신속한 최신 정보 취득이 어려운 투자자들을 돕기 위함이다.\
# \
# **기술 활용 방식:** 코드와 설명서를 배포하거나 서비스 자체를 웹을 만든다.\
# \
# **결과:** 원하는 종목이 실시간 상황에 따라 자동으로 매수, 매도된다.\
# \
# **기술 기대효과:** 빠른 정보 획득이 어려운 투자자들이 수익을 얻을 수 있다.\
# \
# **팀원 역할:**
#
# **이서율:** bard api 이용 및 코드 합쳐서 연결하기, langchain, 한국투자증권 api를 이용해 자동 매수, 매도 프로그램 제작\
# **정인강:** 뉴스 크롤링, 텍스트 분석\
# **박도현:** unity로 interface제작 \
# \
# \
# # *# 파이썬에서 바로 실행시키느라 모듈들 install하는 것들을 로컬에서 했습니다. 그래서 이 코드들은 pip install이 안되있어서 실행은 모듈들이 다 갖춰진 상태에서 해야해요*

# %% [markdown]
# # C#코드

# %%
//첫번째코드:
using System;
using System.Collections;
using System.Collections.Generic;
using System.Diagnostics;
using System.Text;
using UnityEngine;
using UnityEngine.UI;

public class PythonRun : MonoBehaviour
{
    Process process = new Process();
    public string output;
    public InputField key;
    public InputField secret;
    public InputField acc_no;
    public InputField symbol;
    public InputField quantity;
    public InputField code;
    public Text txt;
    public Text txt2;
    public string keyS;
    public string secretS;
    public string accnoS;
    public string symbolS;
    public string quantityS;
    public string codeS;
    bool isStart;
    void Start()
    {
        isStart = true;
        process.StartInfo.FileName = "C:\\Users\\SAMSUNG\\AppData\\Local\\Programs\\Python\\Python310\\python.exe";
        process.StartInfo.Arguments = @"D:\nbjE.py";
        process.StartInfo.CreateNoWindow = true;
        string eOut = null;
        process.ErrorDataReceived += new DataReceivedEventHandler((sender, e) =>
        { eOut += e.Data; });
        process.StartInfo.UseShellExecute = false;
        process.StartInfo.RedirectStandardOutput = true;
        process.StartInfo.RedirectStandardInput = true;
        process.StartInfo.StandardOutputEncoding = Encoding.UTF8;


    }
    private void Update()
    {
        if (Input.GetKeyDown(KeyCode.Space) && isStart)
        {
            StartCoroutine(UpdateCoroutine());
            isStart = false;
        }
    }
    /*
    void Update()
    {
        keyS = key.text;
        secretS = secret.text;
        accnoS = acc_no.text;
        symbolS = symbol.text;
        quantityS = quantity.text;
        codeS = code.text;

        if (Input.GetKeyDown(KeyCode.Space))
        {
            process.Start();
            string koreanString = codeS;
            byte[] encodedBytes = Encoding.UTF8.GetBytes(koreanString);
            string encodedString = Convert.ToBase64String(encodedBytes);
            UnityEngine.Debug.Log(encodedString);
            process.StandardInput.WriteLine(encodedString);

            process.StandardInput.Flush();
            process.StandardInput.Close();

            UnityEngine.Debug.Log("played");
            StringBuilder outputBuilder = new StringBuilder();

            process.OutputDataReceived += new DataReceivedEventHandler((sender, e) =>
            {
                if (!string.IsNullOrEmpty(e.Data))
                {
                    outputBuilder.AppendLine(e.Data);
                }
            });

            process.BeginOutputReadLine();



            while (!process.HasExited)
            {

                yield return null;
            }

            output = outputBuilder.ToString();

            UnityEngine.Debug.Log(output);
        }

    }*/
    IEnumerator UpdateCoroutine()
    {
        //while (true)
        {
            keyS = key.text;
            secretS = secret.text;
            accnoS = acc_no.text;
            symbolS = symbol.text;
            quantityS = quantity.text;
            codeS = code.text;

            //if (Input.GetKeyDown(KeyCode.Space))
            {
                process.Start();
                string koreanString = codeS;
                byte[] encodedBytes = Encoding.UTF8.GetBytes(koreanString);
                string encodedString = Convert.ToBase64String(encodedBytes);
                UnityEngine.Debug.Log(encodedString);
                process.StandardInput.WriteLine(encodedString);
                process.StandardInput.WriteLine(keyS);
                process.StandardInput.WriteLine(secretS);
                process.StandardInput.WriteLine(accnoS);
                process.StandardInput.WriteLine(symbolS);
                process.StandardInput.WriteLine(quantityS);
                process.StandardInput.Flush();
                process.StandardInput.Close();

                UnityEngine.Debug.Log("played");

                StringBuilder outputBuilder = new StringBuilder();

                process.OutputDataReceived += new DataReceivedEventHandler((sender, e) =>
                {
                    if (!string.IsNullOrEmpty(e.Data))
                    {
                        outputBuilder.AppendLine(e.Data);
                    }
                });
                txt2.text = "";
                process.BeginOutputReadLine();
                while (!process.HasExited)
                {
                    txt2.text = "analyzing";
                    yield return null;  // 한 프레임 대기
                }
                txt2.text = "";

                output = outputBuilder.ToString();
                UnityEngine.Debug.Log(output[0]);
                if (output[0] == '0')
                {
                    txt.text = "sell";
                }
                else if (output[0] == '1')
                {
                    txt.text = "buy";
                }
                else
                {
                    txt.text = "stay";
                }

            }

            yield return null;  // 한 프레임 대기
        }
        process = new Process();
        yield return new WaitForSeconds(10);
        process.StartInfo.FileName = "C:\\Users\\SAMSUNG\\AppData\\Local\\Programs\\Python\\Python310\\python.exe";
        process.StartInfo.Arguments = @"D:\nbjE.py";
        process.StartInfo.CreateNoWindow = true;
        string eOut = null;
        process.ErrorDataReceived += new DataReceivedEventHandler((sender, e) =>
        { eOut += e.Data; });
        process.StartInfo.UseShellExecute = false;
        process.StartInfo.RedirectStandardOutput = true;
        process.StartInfo.RedirectStandardInput = true;
        process.StartInfo.StandardOutputEncoding = Encoding.UTF8;
        StartCoroutine(UpdateCoroutine());
    }
}

//두번째코드:
using System.Collections;
using System.Collections.Generic;
using UnityEngine;
using UnityEngine.UIElements;

public class CamMove : MonoBehaviour
{
    // Start is called before the first frame update
    public Vector3 dir;
    public Vector3 dir0;
    public float speed;
    float yRotate;
    float xRotate;
    public int camState;//init:0 login:1 stock:2 move:3
    public Transform[] camPos;
    public GameObject[] uiObj;
    public float moveSpeed;
    private void Awake()
    {
        Application.targetFrameRate = 140;
    }
    void Start()
    {
        moveSpeed = 20;
        camState = 0;
        speed = 40;
        dir0 =  new Vector3(14.4f, 90, 0);
        dir = dir0;
        //yRotate =
    }

    // Update is called once per frame
    void Update()
    {
        if(camState == 0)
        {
            float xRotateMove = -Input.GetAxis("Mouse Y") * Time.deltaTime * speed;
            float yRotateMove = Input.GetAxis("Mouse X") * Time.deltaTime * speed;
            yRotate = transform.eulerAngles.y + yRotateMove;
            //xRotate = transform.eulerAngles.x + xRotateMove;
            xRotate = xRotate + xRotateMove;
            xRotate = Mathf.Clamp(xRotate, -45, 45); // 위, 아래 고정
            yRotate = Mathf.Clamp(yRotate, 45, 135);
            transform.eulerAngles = new Vector3(xRotate, yRotate, 0);
            if (Input.GetMouseButtonDown(0))
            {
                Ray ray = Camera.main.ScreenPointToRay(Input.mousePosition);
                RaycastHit hit;
                int rayerMask = 1 << LayerMask.NameToLayer("Monitor1");
                if (Physics.Raycast(ray, out hit, 1000f, rayerMask))
                {
                    StartCoroutine(stateMove(1));
                }
                ray = Camera.main.ScreenPointToRay(Input.mousePosition);

                rayerMask = 1 << LayerMask.NameToLayer("Monitor2");
                if (Physics.Raycast(ray, out hit, 1000f, rayerMask))
                {

                    StartCoroutine(stateMove(2));
                }
            }
        }
        else
        {
            xRotate = 0;
            yRotate = 90;
            transform.eulerAngles = new Vector3(0, 90, 0);
        }


        if(camState != 3)
        {
            transform.position = camPos[camState].position;
            for(int i = 0; i < 3; i++)
            {
                if(i!=camState)
                    uiObj[i].SetActive(false);
                else
                    uiObj[i].SetActive(true);
            }
        }

    }
    public void stateMoveCall(int a)
    {
        StartCoroutine(stateMove(a));
    }
    IEnumerator stateMove(int a)
    {
        camState = 3;
        while (Vector3.Distance(camPos[a].position, transform.position) > 0.1f)
        {
            transform.position += (camPos[a].position - transform.position).normalized * moveSpeed * Time.deltaTime;
            yield return null;
        }
        camState = a;
    }

}
/*
           process.StandardInput.WriteLine(keyS);
           process.StandardInput.WriteLine(secretS);
           process.StandardInput.WriteLine(accnoS);
           process.StandardInput.WriteLine(symbolS);
           process.StandardInput.WriteLine(quantityS);*/

//세번째코드:
using System.Collections;
using System.Collections.Generic;
using UnityEngine;

public class State1Back : MonoBehaviour
{
    public CamMove camMove;

    // Start is called before the first frame update
    void Start()
    {

    }

    // Update is called once per frame
    void Update()
    {

    }
    public void onClick()
    {
        camMove.stateMoveCall(0);
    }
}

# %% [markdown]
# # python 코드

# %%
from bs4 import BeautifulSoup
import requests
import re
import datetime
from tqdm import tqdm
import sys
from bardapi import Bard
import mojito
import pprint
import time
from time import sleep
import base64
import pandas as pd

# 페이지 url 형식에 맞게 바꾸어 주는 함수 만들기
  #입력된 수를 1, 11, 21, 31 ...만들어 주는 함수
def makePgNum(num):
    if num == 1:
        return num
    elif num == 0:
        return num+1
    else:
        return num+9*(num-1)

# 크롤링할 url 생성하는 함수 만들기(검색어, 크롤링 시작 페이지, 크롤링 종료 페이지)

def makeUrl(search, start_pg, end_pg):
    if start_pg == end_pg:
        start_page = makePgNum(start_pg)
        url = "https://search.naver.com/search.naver?where=news&sm=tab_pge&query=" + search + "&sm=tab_opt&sort=1&photo=0&field=0&pd=0&ds=&de=&docid=&related=0&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so%3Add%2Cp%3Aall&is_sug_officeid=0&office_category=0&service_area=0&nso=so:dd,p:all,a:all&start="+ str(start_page)
        return url
    else:
        urls = []
        for i in range(start_pg, end_pg + 1):
            page = makePgNum(i)
            url = "https://search.naver.com/search.naver?where=news&sm=tab_pge&query=" + search + "&sm=tab_opt&sort=1&photo=0&field=0&pd=0&ds=&de=&docid=&related=0&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so%3Add%2Cp%3Aall&is_sug_officeid=0&office_category=0&service_area=0&nso=so:dd,p:all,a:all&start=" + str(page)
            urls.append(url)
        return urls

# html에서 원하는 속성 추출하는 함수 만들기 (기사, 추출하려는 속성값)
def news_attrs_crawler(articles,attrs):
    attrs_content=[]
    for i in articles:
        attrs_content.append(i.attrs[attrs])
    return attrs_content

# ConnectionError방지
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) Chrome/98.0.4758.102"}

#html생성해서 기사크롤링하는 함수 만들기(url): 링크를 반환
def articles_crawler(url):
    #html 불러오기
    original_html = requests.get(i,headers=headers)
    html = BeautifulSoup(original_html.text, "html.parser")

    url_naver = html.select("div.group_news > ul.list_news > li div.news_area > div.news_info > div.info_group > a.info")
    url = news_attrs_crawler(url_naver,'href')
    return url

#####뉴스크롤링 시작#####

#검색어 입력 #7IK87ISx
search = input()

key = input()
secret = input()
ACC_NO = input()
symbol=input()
quantity=int(input())

decodedBytes = base64.b64decode(search)
search = decodedBytes.decode('utf-8-sig')
#검색 시작할 페이지 입력
page = 1#int(input("\n크롤링할 시작 페이지를 입력해주세요. ex)1(숫자만입력):")) # ex)1 =1페이지,2=2페이지...
#검색 종료할 페이지 입력
page2 = 2#int(input("\n크롤링할 종료 페이지를 입력해주세요. ex)1(숫자만입력):")) # ex)1 =1페이지,2=2페이지...

# naver url 생성
url = makeUrl(search,page,page2)
count=0
while count==0:
    count=1
    #뉴스 크롤러 실행
    news_titles = []
    news_url =[]
    news_contents =[]
    news_dates = []
    for i in url:
        url = articles_crawler(url)
        news_url.append(url)


    #제목, 링크, 내용 1차원 리스트로 꺼내는 함수 생성
    def makeList(newlist, content):
        for i in content:
            for j in i:
                newlist.append(j)
        return newlist


    #제목, 링크, 내용 담을 리스트 생성
    news_url_1 = []

    #1차원 리스트로 만들기(내용 제외)
    makeList(news_url_1,news_url)

    #NAVER 뉴스만 남기기
    final_urls = []
    for i in tqdm(range(len(news_url_1))):
        if "news.naver.com" in news_url_1[i]:
            final_urls.append(news_url_1[i])
        else:
            pass

    # 뉴스 내용 크롤링
    for i in tqdm(final_urls):
        #각 기사 html get하기
        news = requests.get(i,headers=headers)
        news_html = BeautifulSoup(news.text,"html.parser")
        # 뉴스 제목 가져오기
        title = news_html.select_one("#ct > div.media_end_head.go_trans > div.media_end_head_title > h2")
        if title == None:
            title = news_html.select_one("#content > div.end_ct > div > h2")

        # 뉴스 본문 가져오기
        content = news_html.select("article#dic_area")
        if content == []:
            content = news_html.select("#articeBody")

        # 기사 텍스트만 가져오기
        # list합치기
        content = ''.join(str(content))

        # html태그제거 및 텍스트 다듬기
        pattern1 = '<[^>]*>'
        title = re.sub(pattern=pattern1, repl='', string=str(title))
        content = re.sub(pattern=pattern1, repl='', string=content)
        pattern2 = """[\n\n\n\n\n// flash 오류를 우회하기 위한 함수 추가\nfunction _flash_removeCallback() {}"""
        content = content.replace(pattern2, '')

        news_titles.append(title)
        news_contents.append(content)

        try:
            html_date = news_html.select_one("div#ct> div.media_end_head.go_trans > div.media_end_head_info.nv_notrans > div.media_end_head_info_datestamp > div > span")
            news_date = html_date.attrs['data-date-time']
        except AttributeError:
            news_date = news_html.select_one("#content > div.end_ct > div > div.article_info > span > em")
        news_date = re.sub(pattern=pattern1,repl='',string=str(news_date))
        # 날짜 가져오기
        news_dates.append(news_date)
    i=0
    while news_dates[i]=="None":
        i=i+1

    #—————————————————


    import os
    import openai
    import chromadb
    import langchain
    os.environ["OPENAI_API_KEY"] = "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"

    openai.api_key = os.getenv("OPENAI_API_KEY")
    from collections import namedtuple

    # Document라는 이름의 namedtuple 정의
    Document = namedtuple('Document', ['page_content', 'metadata'])

    # 주어진 텍스트
    text = news_contents[i]

    # Document 객체 생성
    doc = Document(page_content=text, metadata={'source': 'user-generated'})

    # 리스트에 담기
    documents = [doc]
     # 5. Text Split(GPT API Token Limit)

    from langchain.text_splitter import TokenTextSplitter

    text_splitter = TokenTextSplitter(chunk_size=1000, chunk_overlap=0)
    doc = text_splitter.split_documents(documents)
    # 6. Vetor Store에 텍스트 벡터값 저장(검색가능함)

    from langchain.embeddings.openai import OpenAIEmbeddings
    from langchain.vectorstores import Chroma

    embeddings = OpenAIEmbeddings(
        model='text-embedding-ada-002') # 사람이 인식하는 문자 -> 컴퓨터 인식 벡터 모델
    vectorstore = Chroma.from_documents(doc, embeddings) # 문자 -> 벡터 변환해서 벡터 스토리지에 저장
    retriever = vectorstore.as_retriever(search_type="similarity", search_kwargs={"k":3})
    # 리트리버 벡터 문서 -> LLM 모델 인식할 수 있는 텍스트 문서로 반환/조회
    # 7. LLM 연결

    from langchain.chat_models import ChatOpenAI

    chat_llm = ChatOpenAI(
        model_name="ft:gpt-3.5-turbo-0613:swhub-ai::8CAmPtqC",
        temperature=0
    )
    # 8. Chain 연결

    from langchain.chains import RetrievalQA

    qa = RetrievalQA.from_chain_type(
        llm=chat_llm,
        chain_type="stuff",
        retriever=retriever,
        return_source_documents=True)
    # 9. 질의
    query = "위 글이 sk하이닉스에게 긍정적인 내용인지 부정적인 내용인지 알려줘"
    result = qa({"query": query})

    metta=(result["result"], result["source_documents"][0].metadata)
    #print(metta)

    datetime_format = "%Y-%m-%d %H:%M:%S"

    datetime_result = datetime.datetime.strptime(news_dates[i], datetime_format)
    dateDiff = datetime.datetime.now()-datetime_result
    if dateDiff.seconds / 3600 > 24:
        print("최신뉴스가 없어요")
    else:
        '''
        key = "PSIQ599g3fqtNUhwzRRJwH1oJGWSTpftdYVM"
        secret = "RZkYtlntKFzVRN7678QBwZCk01Img7WgaTP1cNOciyGxAbBDj7z/5y4+v9jZoHrLmkO/bMWCB7+lIwTj5gfgIQlmb5jRsXWIEJvSuDDUaBsiT/PLRLxm6vxGVG58rxij21wLu5I6LkvwW+XhzLCvvbCdNcbHuxdwMRbMTosaI963J7imvaI="
        ACC_NO = "50096816-01"
        symbol='000660'
        quantity=1
        '''
        broker = mojito.KoreaInvestment(api_key=key, api_secret=secret, acc_no=ACC_NO, mock=True)
        resp2 = broker.fetch_balance()


        broker = mojito.KoreaInvestment(api_key=key, api_secret=secret, acc_no=ACC_NO, mock=True)
        prev_inza=None
        #텍스트 개수 파악
        buy_count = metta.count('긍정')
        sell_count = metta.count('부정')

        #비교
        if buy_count > sell_count:
            inza = 1
        else:
            inza = 0
        print(inza)
        if inza == prev_inza:
            asdfq=10
        else:
            if inza == 1:
                resp = broker.create_market_buy_order(symbol,quantity)
            elif inza == 0:
                resp = broker.create_market_sell_order(symbol, quantity)

            pprint.pprint(resp)

            prev_inza = inza


        content_1 = news_contents[i]
        sys.exit()
        #time.sleep(300)


    #--------------------------------------------------------------------------
